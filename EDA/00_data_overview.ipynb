# %% [markdown]
# ##

# %%
from mdq.data import load_data

business, consumer, merchants, mcc = load_data()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 from mdq.data import load_data
#       3 business, consumer, merchants, mcc = load_data()
#
# ModuleNotFoundError: No module named 'mdq'
